# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fast')

# %% [markdown]
# # EXPERIMENTAL

# %% [markdown]
# # SWING

# %%
number_jobs = 100
experiment_ID = "arf7_21h_6t_RNAseq"
                
pathway_data = f"C:/Users/ivana/OneDrive/Desktop/Internship New Folder/Analysis Experimental Data/Results_instances-1000/Results_SWING_arf7_21h_6t_RNAseq_genes-157"

mean_important_array_SWING = np.array([])
mean_important_array_rand_SWING = np.array([])
mean_important_array_crand_SWING = np.array([])

end = 0
for j in range(number_jobs):
    
    first = end + 1
    end = end + 10
                                                                                        
    mean_importance_file = pd.read_csv(f"{pathway_data}/Mean_Importance_{experiment_ID}/ranking_SWING_arf7_21h_6t_RNAseq_range{first}-{end}.txt", sep = "\t")                                                                                             
    mean_importance_file_rand = pd.read_csv(f"{pathway_data}/Mean_Importance_{experiment_ID}_rand/ranking_SWING_rand_arf7_21h_6t_RNAseq_range{first}-{end}.txt", sep = "\t")
    mean_importance_file_crand = pd.read_csv(f"{pathway_data}/Mean_Importance_{experiment_ID}_crand/ranking_SWING_crand_arf7_21h_6t_RNAseq_range{first}-{end}.txt", sep = "\t")
    
    mean_important_array_SWING = np.append(mean_important_array_SWING, mean_importance_file[f"mean_importance"].values)
    mean_important_array_rand_SWING= np.append(mean_important_array_rand_SWING, mean_importance_file_rand[f"mean_importance"].values)
    mean_important_array_crand_SWING= np.append(mean_important_array_crand_SWING, mean_importance_file_crand[f"mean_importance"].values)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_892/3098864724.py in <module>
#      15
#      16     mean_importance_file = pd.read_csv(f"{pathway_data}/Mean_Importance_{experiment_ID}/ranking_SWING_arf7_21h_6t_RNAseq_range{first}-{end}.txt", sep = "\t")
# ---> 17     mean_importance_file_rand = pd.read_csv(f"{pathway_data}/Mean_Importance_{experiment_ID}_rand/ranking_SWING_rand_arf7_21h_6t_RNAseq_range{first}-{end}.txt", sep = "\t")
#      18     mean_importance_file_crand = pd.read_csv(f"{pathway_data}/Mean_Importance_{experiment_ID}_crand/ranking_SWING_crand_arf7_21h_6t_RNAseq_range{first}-{end}.txt", sep = "\t")
#      19
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
# --> 225                 data = _concatenate_chunks(chunks)
#     226
#     227             else:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in _concatenate_chunks(chunks)
#     385                 )
#     386             else:
# --> 387                 result[name] = np.concatenate(arrs)
#     388
#     389     if warning_columns:
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
figure = plt.figure(figsize=(8,5))
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
plt.rcParams["font.family"] = "serif"

y, x, _ = plt.hist(mean_important_array_SWING, bins = 200, color = "midnightblue", density =1, label = r"Normal data")
y_rand, x_rand, _ = plt.hist(mean_important_array_rand_SWING, bins = 200, color='mediumspringgreen', alpha = 0.41, density = 1, label = r"Data shuffled in time")
y_crand, x_crand, _ = plt.hist(mean_important_array_crand_SWING, bins = 200, color='k', alpha = 0.3, density = 1, label = r"Data fully shuffled")

plt.ylabel("Normalized frequency", fontsize = 20)
plt.xlabel("Rank of importance interactions", fontsize = 20)
plt.title("SWING arf19 157 genes", fontsize = 30)
plt.xlim(0,0.01)
plt.legend(prop={"size":15.5, "family":"serif"})
plt.savefig(f"Histogram_SWING_arf19_157_genes.png", bbox_inches="tight", dpi=100 )

#Statistics
print("mean: ", mean_important_array_SWING.mean())
print("mean rand: ", mean_important_array_rand_SWING.mean())
print("estandard desv: ", mean_important_array_SWING.std())
print("estandard desv rand: ", mean_important_array_rand_SWING.std())

print("most frequent value: ", x.max(), " ", y.max())
print("most frequent value rand: ",  x_rand.max(), " ", y_rand.max())
# Out:
# mean:  0.002123975052356543
# mean rand:  0.0021224898442553084
# estandard desv:  0.001477756171702019
# estandard desv rand:  0.0010737089768977238
# most frequent value:  0.0284159079738558   353.3983927939454
# most frequent value rand:  0.0151751647843647   505.50716130842653

# %% [markdown]
# # dynGENIE3

# %%
number_jobs = 100
experiment_ID = "arf7_21h_6t_RNAseq"
header_list = ["Cause Gene", "Effect Gene", "mean_importance"]
pathway_data = f"C:/Users/ivana/OneDrive/Desktop/Internship New Folder/Analysis Experimental Data/Results_instances-1000/Results_dynGENIE3_arf7_21h_6t_RNAseq_genes-157"

mean_important_array_dynGENIE3 = np.array([])
mean_important_array_rand_dynGENIE3 = np.array([])
mean_important_array_crand_dynGENIE3 = np.array([])

end = 0
for j in range(number_jobs):
    
    first = end + 1
    end = end + 10

    mean_importance_file = pd.read_csv(f"{pathway_data}/Mean_Importance_{experiment_ID}/ranking_dynGENIE3_arf7_21h_6t_RNAseq_range{first}-{end}.txt", sep = "\t", names = header_list)
    mean_importance_file_rand = pd.read_csv(f"{pathway_data}/Mean_Importance_{experiment_ID}_rand/ranking_dynGENIE3_rand_arf7_21h_6t_RNAseq_range{first}-{end}.txt", sep = "\t", names = header_list)
    mean_importance_file_crand = pd.read_csv(f"{pathway_data}/Mean_Importance_{experiment_ID}_crand/ranking_dynGENIE3_crand_arf7_21h_6t_RNAseq_range{first}-{end}.txt", sep = "\t", names = header_list)
   
    mean_important_array_dynGENIE3 = np.append(mean_important_array_dynGENIE3, mean_importance_file[f"mean_importance"].values)
    mean_important_array_rand_dynGENIE3 = np.append(mean_important_array_rand_dynGENIE3, mean_importance_file_rand[f"mean_importance"].values)
    mean_important_array_crand_dynGENIE3 = np.append(mean_important_array_crand_dynGENIE3, mean_importance_file_crand[f"mean_importance"].values)

# %%
figure = plt.figure(figsize=(8,5))
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
plt.rcParams["font.family"] = "serif"

y, x, _ = plt.hist(mean_important_array_dynGENIE3, bins = 200, color = "midnightblue", density =1, label = r"Normal data")
y_rand, x_rand, _ = plt.hist(mean_important_array_rand_dynGENIE3, bins = 200,color='mediumspringgreen', alpha = 0.41, density = 1, label = r"Data shuffled in time")
y_crand, x_crand, _ = plt.hist(mean_important_array_crand_dynGENIE3, bins = 200,color='k', alpha = 0.4, density = 1, label = r"Data fully shuffled")

plt.ylabel("Normalized frequency", fontsize = 20, family = "serif")
plt.xlabel("Rank of importance interactions", fontsize = 20)
plt.title("dynGENIE3 arf19 157 genes", fontsize = 30)
plt.xlim(0.0,0.03)
plt.legend(prop={"size":15.5, "family":"serif"})

plt.savefig(f"Histogram_dynGENIE3_arf19_157_genes.png", bbox_inches="tight", dpi=100 )

#Statistics
print("mean: ", mean_important_array_dynGENIE3.mean())
print("mean rand: ", mean_important_array_rand_dynGENIE3.mean())
print("estandard desv: ", mean_important_array_dynGENIE3.std())
print("estandard desv rand: ", mean_important_array_rand_dynGENIE3.std())
print("most frequent value: ", x.max(), " ", y.max())
print("most frequent value rand: ",  x_rand.max(), " ", y_rand.max())
# Out:
# mean:  0.006410256218765309
# mean rand:  0.006410256418830641
# estandard desv:  0.008314279077312473
# estandard desv rand:  0.0067664558476330065
# most frequent value:  0.097121   200.39958741415725
# most frequent value rand:  0.091574   150.42214831542154
